# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Chargement des Datasets

# %%
df_constructors = pd.read_csv('../data/outputs/04_constructors_processed.csv')
df_drivers = pd.read_csv('../data/outputs/03_drivers_processed.csv')
df_races_results = pd.read_csv('../data/outputs/02_races_results.csv')

# %%
df_constructors.head()
# Out:
#    constructorId        name nationality  constructor_is_active
# 0              1     McLaren     British                      1
# 1              2  BMW Sauber      German                      0
# 2              3    Williams     British                      1
# 3              4     Renault      French                      0
# 4              5  Toro Rosso     Italian                      0

# %%
df_drivers.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url  \
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen
#
#    driver_is_active  age
# 0                 1   39
# 1                 0   47
# 2                 0   39
# 3                 1   43
# 4                 0   43

# %%
df_races_results.head()
# Out:
#    resultId  raceId  driverId  constructorId  grid  positionOrder  points  \
# 0         1      18         1              1     1              1    10.0
# 1         2      18         2              2     5              2     8.0
# 2         3      18         3              3     7              3     6.0
# 3         4      18         4              4    11              4     5.0
# 4         5      18         5              1     3              5     4.0
#
#    laps  milliseconds  fastestLap  fastestLapTime  fastestLapSpeed  statusId  \
# 0    58       5690616          39           87452          218.300         1
# 1    58       5696094          41           87739          217.586         1
# 2    58       5698779          41           88090          216.719         1
# 3    58       5707797          58           88603          215.464         1
# 4    58       5708630          43           87418          218.385         1
#
#    year  round  circuitId                   name
# 0  2008      1          1  Australian Grand Prix
# 1  2008      1          1  Australian Grand Prix
# 2  2008      1          1  Australian Grand Prix
# 3  2008      1          1  Australian Grand Prix
# 4  2008      1          1  Australian Grand Prix

# %% [markdown]
# ## 2. Remove unnecessaries fields

# %%
df_races_results.drop(['points', 'laps', 'milliseconds', 'fastestLap', 'fastestLapTime', 'fastestLapSpeed'], axis=1, inplace=True)

# %%
df_races_results.head()
# Out:
#    resultId  raceId  driverId  constructorId  grid  positionOrder  statusId  \
# 0         1      18         1              1     1              1         1
# 1         2      18         2              2     5              2         1
# 2         3      18         3              3     7              3         1
# 3         4      18         4              4    11              4         1
# 4         5      18         5              1     3              5         1
#
#    year  round  circuitId                   name
# 0  2008      1          1  Australian Grand Prix
# 1  2008      1          1  Australian Grand Prix
# 2  2008      1          1  Australian Grand Prix
# 3  2008      1          1  Australian Grand Prix
# 4  2008      1          1  Australian Grand Prix

# %% [markdown]
# ## 3. Merging the 3 Data sets

# %% [markdown]
# ### 3.1. Rename some fields before merging

# %%
df_races_results.rename({'name': 'circuit_name'}, axis=1, inplace=True)
df_constructors.rename({'name': 'constructor_name'}, axis=1, inplace=True)

# %% [markdown]
# ### 3.2. Merging constructors and races

# %%
df_const_race = df_races_results.merge(
    df_constructors[
        ['constructorId', 'constructor_name', 'constructor_is_active', 'constructor_races_won', 'constructor_avg_point', 'constructor_times_in_top_10']
        ], on='constructorId', how='inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 2
#       1 df_const_race = df_races_results.merge(
# ----> 2     df_constructors[
#       3         ['constructorId', 'constructor_name', 'constructor_is_active', 'constructor_races_won', 'constructor_avg_point', 'constructor_times_in_top_10']
#       4         ], on='constructorId', how='inner')
#
# File ~/Projects/Personal/project_ia_f1_gp_predictor/.venv/lib/python3.9/site-packages/pandas/core/frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Projects/Personal/project_ia_f1_gp_predictor/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:6199, in Index._get_indexer_strict(self, key, axis_name)
#    6196 else:
#    6197     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6199 self._raise_if_missing(keyarr, indexer, axis_name)
#    6201 keyarr = self.take(indexer)
#    6202 if isinstance(key, Index):
#    6203     # GH 42790 - Preserve name from an Index
#
# File ~/Projects/Personal/project_ia_f1_gp_predictor/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:6251, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6248     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6251 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['constructor_races_won', 'constructor_avg_point', 'constructor_times_in_top_10'] not in index"

# %%
df_const_race.head()
# Out:
#    resultId  raceId  driverId  constructorId  grid  positionOrder  statusId  \
# 0         1      18         1              1     1              1         1
# 1         2      18         2              2     5              2         1
# 2         3      18         3              3     7              3         1
# 3         4      18         4              4    11              4         1
# 4         5      18         5              1     3              5         1
#
#    year  round  circuitId           circuit_name constructor_name  \
# 0  2008      1          1  Australian Grand Prix          McLaren
# 1  2008      1          1  Australian Grand Prix       BMW Sauber
# 2  2008      1          1  Australian Grand Prix         Williams
# 3  2008      1          1  Australian Grand Prix          Renault
# 4  2008      1          1  Australian Grand Prix          McLaren
#
#    constructor_is_active  constructor_races_won  constructor_avg_point  \
# 0                      1                    179               3.364151
# 1                      0                      1               2.200000
# 2                      1                    114               2.243008
# 3                      0                     35               2.257942
# 4                      1                    179               3.364151
#
#    constructor_times_in_top_10
# 0                         1110
# 1                           91
# 2                          764
# 3                          390
# 4                         1110

# %% [markdown]
# ### 3.3. Merging all

# %%
df_drivers.head()
# Out:
#    driverId number code  forename     surname         dob nationality  \
# 0         1     44  HAM     Lewis    Hamilton  1985-01-07     British
# 1         2     \N  HEI      Nick    Heidfeld  1977-05-10      German
# 2         3      6  ROS      Nico     Rosberg  1985-06-27      German
# 3         4     14  ALO  Fernando      Alonso  1981-07-29     Spanish
# 4         5     \N  KOV    Heikki  Kovalainen  1981-10-19     Finnish
#
#    driver_is_active  driver_avg_point  driver_avg_speed  race_end_bf_2019  \
# 0                 1         14.100932        205.711759               193
# 1                 0          1.407609        204.044578                66
# 2                 0          7.740291        200.290369               145
# 3                 1          5.954054        204.462531               202
# 4                 0          0.937500        198.246165                39
#
#    race_end_in_2019  race_end_in_2020  race_end_in_2021  race_end_in_2022  \
# 0                21                16                21                19
# 1                 0                 0                 0                 0
# 2                 0                 0                 0                 0
# 3                 0                 0                11                12
# 4                 0                 0                 0                 0
#
#    race_end_in_2023  driver_most_won_circuit_id  driver_nber_of_races_won  \
# 0                12                           9                       103
# 1                 0                           0                         0
# 2                 0                           6                        23
# 3                12                           3                        32
# 4                 0                          11                         1
#
#    driver_nber_of_times_in_top_10  age
# 0                             283   39
# 1                             101   47
# 2                             144   39
# 3                             250   43
# 4                              36   43

# %% [markdown]
# #### a) Select the fields that we need to use

# %%
cols = df_drivers.columns.to_list()
cols.remove('number')
cols.remove('code')
cols.remove('nationality')

# %%
df_drivers[cols].head()
# Out:
#    driverId  forename     surname         dob  driver_is_active  \
# 0         1     Lewis    Hamilton  1985-01-07                 1
# 1         2      Nick    Heidfeld  1977-05-10                 0
# 2         3      Nico     Rosberg  1985-06-27                 0
# 3         4  Fernando      Alonso  1981-07-29                 1
# 4         5    Heikki  Kovalainen  1981-10-19                 0
#
#    driver_avg_point  driver_avg_speed  race_end_bf_2019  race_end_in_2019  \
# 0         14.100932        205.711759               193                21
# 1          1.407609        204.044578                66                 0
# 2          7.740291        200.290369               145                 0
# 3          5.954054        204.462531               202                 0
# 4          0.937500        198.246165                39                 0
#
#    race_end_in_2020  race_end_in_2021  race_end_in_2022  race_end_in_2023  \
# 0                16                21                19                12
# 1                 0                 0                 0                 0
# 2                 0                 0                 0                 0
# 3                 0                11                12                12
# 4                 0                 0                 0                 0
#
#    driver_most_won_circuit_id  driver_nber_of_races_won  \
# 0                           9                       103
# 1                           0                         0
# 2                           6                        23
# 3                           3                        32
# 4                          11                         1
#
#    driver_nber_of_times_in_top_10  age
# 0                             283   39
# 1                             101   47
# 2                             144   39
# 3                             250   43
# 4                              36   43

# %% [markdown]
# #### b) Concatenate forename and surname

# %%
df_drivers['full_name'] = df_drivers['forename'] + ' ' + df_drivers['surname']

# %%
cols.append('full_name')

# %% [markdown]
# #### c) Let's merge

# %%
df_merged = df_const_race.merge(df_drivers[cols], on='driverId', how='inner')

# %%
print(df_merged.shape)
df_merged.head()
# Out:
# (26080, 33)
#    resultId  raceId  driverId  constructorId  grid  positionOrder  statusId  \
# 0         1      18         1              1     1              1         1
# 1         2      18         2              2     5              2         1
# 2         3      18         3              3     7              3         1
# 3         4      18         4              4    11              4         1
# 4         5      18         5              1     3              5         1
#
#    year  round  circuitId  ... race_end_in_2019 race_end_in_2020  \
# 0  2008      1          1  ...               21               16
# 1  2008      1          1  ...                0                0
# 2  2008      1          1  ...                0                0
# 3  2008      1          1  ...                0                0
# 4  2008      1          1  ...                0                0
#
#    race_end_in_2021  race_end_in_2022  race_end_in_2023  \
# 0                21                19                12
# 1                 0                 0                 0
# 2                 0                 0                 0
# 3                11                12                12
# 4                 0                 0                 0
#
#    driver_most_won_circuit_id driver_nber_of_races_won  \
# 0                           9                      103
# 1                           0                        0
# 2                           6                       23
# 3                           3                       32
# 4                          11                        1
#
#   driver_nber_of_times_in_top_10 age          full_name
# 0                            283  39     Lewis Hamilton
# 1                            101  47      Nick Heidfeld
# 2                            144  39       Nico Rosberg
# 3                            250  43    Fernando Alonso
# 4                             36  43  Heikki Kovalainen
#
# [5 rows x 33 columns]

# %% [markdown]
# ## 4. Calculate the age of the driver for each race

# %%
def calcul_age(row):
    return row['year'] - row['dob'].year

# %%
df_merged['dob'] = pd.to_datetime(df_merged['dob'])
df_merged['season_age'] = df_merged.apply(calcul_age, axis=1)

# %%
df_merged.head()
# Out:
#    resultId  raceId  driverId  constructorId  grid  positionOrder  statusId  \
# 0         1      18         1              1     1              1         1
# 1         2      18         2              2     5              2         1
# 2         3      18         3              3     7              3         1
# 3         4      18         4              4    11              4         1
# 4         5      18         5              1     3              5         1
#
#    year  round  circuitId  ... race_end_in_2020 race_end_in_2021  \
# 0  2008      1          1  ...               16               21
# 1  2008      1          1  ...                0                0
# 2  2008      1          1  ...                0                0
# 3  2008      1          1  ...                0               11
# 4  2008      1          1  ...                0                0
#
#    race_end_in_2022  race_end_in_2023  driver_most_won_circuit_id  \
# 0                19                12                           9
# 1                 0                 0                           0
# 2                 0                 0                           6
# 3                12                12                           3
# 4                 0                 0                          11
#
#    driver_nber_of_races_won driver_nber_of_times_in_top_10 age  \
# 0                       103                            283  39
# 1                         0                            101  47
# 2                        23                            144  39
# 3                        32                            250  43
# 4                         1                             36  43
#
#            full_name  season_age
# 0     Lewis Hamilton          23
# 1      Nick Heidfeld          31
# 2       Nico Rosberg          23
# 3    Fernando Alonso          27
# 4  Heikki Kovalainen          27
#
# [5 rows x 34 columns]

# %%
df_merged.drop(['dob', 'forename','surname', 'age'], axis=1, inplace=True)

# %% [markdown]
# ## 5. Export the Data set with string data values (for further analysis)

# %%
df_merged.to_csv('../data/outputs/05_merged_data.csv', index=False)

# %% [markdown]
# ## 6. Export the Data set for the first model

# %%
df_merged.select_dtypes(np.object_).head()
# Out:
#             circuit_name constructor_name          full_name
# 0  Australian Grand Prix          McLaren     Lewis Hamilton
# 1  Australian Grand Prix       BMW Sauber      Nick Heidfeld
# 2  Australian Grand Prix         Williams       Nico Rosberg
# 3  Australian Grand Prix          Renault    Fernando Alonso
# 4  Australian Grand Prix          McLaren  Heikki Kovalainen

# %% [markdown]
# ### 6.1 Drop categoricals values

# %%
cols = df_merged.select_dtypes(np.object_).columns

# %%
df_merged_v2 = df_merged.drop(cols, axis=1)

# %%
df_merged_v2.head()
# Out:
#    resultId  raceId  driverId  constructorId  grid  positionOrder  statusId  \
# 0         1      18         1              1     1              1         1
# 1         2      18         2              2     5              2         1
# 2         3      18         3              3     7              3         1
# 3         4      18         4              4    11              4         1
# 4         5      18         5              1     3              5         1
#
#    year  round  circuitId  ...  race_end_bf_2019  race_end_in_2019  \
# 0  2008      1          1  ...               193                21
# 1  2008      1          1  ...                66                 0
# 2  2008      1          1  ...               145                 0
# 3  2008      1          1  ...               202                 0
# 4  2008      1          1  ...                39                 0
#
#    race_end_in_2020  race_end_in_2021  race_end_in_2022  race_end_in_2023  \
# 0                16                21                19                12
# 1                 0                 0                 0                 0
# 2                 0                 0                 0                 0
# 3                 0                11                12                12
# 4                 0                 0                 0                 0
#
#    driver_most_won_circuit_id  driver_nber_of_races_won  \
# 0                           9                       103
# 1                           0                         0
# 2                           6                        23
# 3                           3                        32
# 4                          11                         1
#
#    driver_nber_of_times_in_top_10  season_age
# 0                             283          23
# 1                             101          31
# 2                             144          23
# 3                             250          27
# 4                              36          27
#
# [5 rows x 27 columns]

# %% [markdown]
# ### 6.2. Rename positionOrder order to race_rank

# %%
df_merged_v2.rename({'positionOrder': 'race_rank'}, axis=1, inplace=True)
df_merged_v2.head()
# Out:
#    resultId  raceId  driverId  constructorId  grid  race_rank  statusId  year  \
# 0         1      18         1              1     1          1         1  2008
# 1         2      18         2              2     5          2         1  2008
# 2         3      18         3              3     7          3         1  2008
# 3         4      18         4              4    11          4         1  2008
# 4         5      18         5              1     3          5         1  2008
#
#    round  circuitId  ...  race_end_bf_2019  race_end_in_2019  \
# 0      1          1  ...               193                21
# 1      1          1  ...                66                 0
# 2      1          1  ...               145                 0
# 3      1          1  ...               202                 0
# 4      1          1  ...                39                 0
#
#    race_end_in_2020  race_end_in_2021  race_end_in_2022  race_end_in_2023  \
# 0                16                21                19                12
# 1                 0                 0                 0                 0
# 2                 0                 0                 0                 0
# 3                 0                11                12                12
# 4                 0                 0                 0                 0
#
#    driver_most_won_circuit_id  driver_nber_of_races_won  \
# 0                           9                       103
# 1                           0                         0
# 2                           6                        23
# 3                           3                        32
# 4                          11                         1
#
#    driver_nber_of_times_in_top_10  season_age
# 0                             283          23
# 1                             101          31
# 2                             144          23
# 3                             250          27
# 4                              36          27
#
# [5 rows x 27 columns]

# %% [markdown]
# ### 6.2. Export the dataset

# %%
df_merged_v2.to_csv('../data/outputs/06_final_dataset.csv', index=False)
