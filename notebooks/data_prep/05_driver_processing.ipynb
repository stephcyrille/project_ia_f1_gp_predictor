# %% [markdown]
# Traitements à faire
# ---
# - Retirer les colonnes inutilisées
# - Ajouter une étique pour les pilotes actifs à la dernière saison (2023)

# %%
import pandas as pd

# %% [markdown]
# ## 1. Chargement du Dataset

# %%
df_drivers = pd.read_csv("../../data/inputs/drivers.csv")

# %%
df_drivers.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %% [markdown]
# ## 2. Retirer les colonnes inutilisées

# %%
df_drivers.drop(['driverRef', 'url', 'code'], axis=1, inplace=True)
df_drivers.head()
# Out:
#    driverId number  forename     surname         dob nationality
# 0         1     44     Lewis    Hamilton  1985-01-07     British
# 1         2     \N      Nick    Heidfeld  1977-05-10      German
# 2         3      6      Nico     Rosberg  1985-06-27      German
# 3         4     14  Fernando      Alonso  1981-07-29     Spanish
# 4         5     \N    Heikki  Kovalainen  1981-10-19     Finnish

# %% [markdown]
# ## 3. Ajouter une étique uniquement sur les pilotes encore actifs

# %%
df_drivers['driver_is_active'] = 0

# %%
# Liste des pilotes actifs actuels
list_drivers = [
    ("Max", "Verstappen"),
    ("Logan", "Sargeant"),
    ("Lando", "Norris"),
    ("Pierre", "Gasly"),
    ("Sergio", "Pérez"),
    ("Fernando", "Alonso"),
    ("Charles", "Leclerc"),
    ("Lance", "Stroll"),
    ("Kevin", "Magnussen"),
    ("Yuki", "Tsunoda"),
    ("Alexander", "Albon"),
    ("Esteban", "Ocon"),
    ("Lewis", "Hamilton"),
    ("Carlos", "Sainz"),
    ("George", "Russell"),
    ("Oscar", "Piastri"),
    ("Guanyu", "Zhou"),
    ("Nico", "Hülkenberg"),
    ("Valtteri", "Bottas"),
    ("Daniel", "Ricciardo"),
]

# %%
# Ajouter l'étique en fonction de la correspondance nom et prénom du pilote dans le Dataset
for (name, surname) in list_drivers:
    df_drivers.loc[(df_drivers['forename'] == name) & (df_drivers['surname'] == surname), 'driver_is_active'] = 1

df_drivers[df_drivers.driver_is_active == 1]
# Out:
#      driverId number   forename     surname         dob nationality  \
# 0           1     44      Lewis    Hamilton  1985-01-07     British
# 3           4     14   Fernando      Alonso  1981-07-29     Spanish
# 452       842     10     Pierre       Gasly  1996-02-07      French
# 807       807     27       Nico  Hülkenberg  1987-08-19      German
# 814       815     11     Sergio       Pérez  1990-01-26     Mexican
# 816       817      3     Daniel   Ricciardo  1989-07-01  Australian
# 821       822     77   Valtteri      Bottas  1989-08-28     Finnish
# 824       825     20      Kevin   Magnussen  1992-10-05      Danish
# 829       830     33        Max  Verstappen  1997-09-30       Dutch
# 831       832     55     Carlos       Sainz  1994-09-01     Spanish
# 838       839     31    Esteban        Ocon  1996-09-17      French
# 839       840     18      Lance      Stroll  1998-10-29    Canadian
# 842       844     16    Charles     Leclerc  1997-10-16  Monegasque
# ...

# %% [markdown]
# ## 4. Exportons le Dataset

# %%
df_drivers.to_csv('../../data/outputs/03_drivers_processed.csv', index=False)
