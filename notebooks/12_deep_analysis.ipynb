# %%
import pandas as pd

# %%
from libs.plot_utils import plot_boxplots
from libs.transformer_utils import remove_outliers

# %% [markdown]
# ## 1. Loading the Dataset

# %%
df = pd.read_csv('../data/outputs/06_final_dataset.csv')

# %%
df['constructor_avg_point'].asfreq
# Out:
# <bound method NDFrame.asfreq of 0        3.364151
# 1        2.200000
# 2        2.243008
# 3        2.257942
# 4        3.364151
#            ...
# 26075    1.965753
# 26076    2.243008
# 26077    0.772436
# 26078    4.343429
# 26079    3.364151
# Name: constructor_avg_point, Length: 26080, dtype: float64>

# %%
print(df.shape)
df.head()
# Out:
# (26080, 28)
#    resultId  raceId  driverId  constructorId  grid  race_rank  statusId  year  \
# 0         1      18         1              1     1          2         1  2008
# 1         2      18         2              2     5          3         1  2008
# 2         3      18         3              3     7          5         1  2008
# 3         4      18         4              4    11          7         1  2008
# 4         5      18         5              1     3          1         1  2008
#
#    round  circuitId  ...  race_end_in_2019  race_end_in_2020  \
# 0      1          1  ...                21                16
# 1      1          1  ...                 0                 0
# 2      1          1  ...                 0                 0
# 3      1          1  ...                 0                 0
# 4      1          1  ...                 0                 0
#
#    race_end_in_2021  race_end_in_2022  race_end_in_2023  \
# 0                21                19                12
# 1                 0                 0                 0
# 2                 0                 0                 0
# 3                11                12                12
# 4                 0                 0                 0
#
#    driver_most_won_circuit_id  driver_nber_of_races_won  \
# 0                          14                        63
# 1                           2                         2
# 2                           3                        20
# 3                           9                        22
# 4                           1                         2
#
#    driver_nber_of_times_in_top_10  age  season_age
# 0                             292   39          23
# 1                             131   47          31
# 2                             158   39          23
# 3                             285   43          27
# 4                              37   43          27
#
# [5 rows x 28 columns]

# %% [markdown]
# ## 2. Dispersion analysis

# %% [markdown]
# ### 2.1. The whole Dataset boxplot

# %%
box_cols = ['driver_avg_speed', 'constructor_avg_point', 'driver_avg_point', 'constructor_races_won', 'race_end_bf_2019', 
        'race_end_in_2019', 'race_end_in_2020', 'race_end_in_2021', 'race_end_in_2022', 'race_end_in_2023', 'driver_nber_of_races_won', 
        'driver_nber_of_times_in_top_10']

# %%
plot_boxplots(df, box_cols)

# %%
df.fillna(0, inplace=True)

# %%
for col in box_cols:
    print(col)
    df.loc[:, col] = remove_outliers(df[col].fillna(0))
# Out:
# driver_avg_speed
# constructor_avg_point
# driver_avg_point
# constructor_races_won
# race_end_bf_2019
# race_end_in_2019
# race_end_in_2020
# race_end_in_2021
# race_end_in_2022
# race_end_in_2023
# driver_nber_of_races_won
# driver_nber_of_times_in_top_10
# /var/folders/53/tlvpf6d56dx58q4nxdlvljmh0000gn/T/ipykernel_40786/2743543921.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[193.  66. 145. ...  83.  28.   0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, col] = remove_outliers(df[col].fillna(0))
# /var/folders/53/tlvpf6d56dx58q4nxdlvljmh0000gn/T/ipykernel_40786/2743543921.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[nan  0.  0. ...  7. 10.  0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, col] = remove_outliers(df[col].fillna(0))
# /var/folders/53/tlvpf6d56dx58q4nxdlvljmh0000gn/T/ipykernel_40786/2743543921.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[nan  0.  0. ...  2. 10.  0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, col] = remove_outliers(df[col].fillna(0))
# /var/folders/53/tlvpf6d56dx58q4nxdlvljmh0000gn/T/ipykernel_40786/2743543921.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[nan  0.  0. ...  0. nan  0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, col] = remove_outliers(df[col].fillna(0))
# /var/folders/53/tlvpf6d56dx58q4nxdlvljmh0000gn/T/ipykernel_40786/2743543921.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[nan  0.  0. ...  2. 16.  0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, col] = remove_outliers(df[col].fillna(0))
# /var/folders/53/tlvpf6d56dx58q4nxdlvljmh0000gn/T/ipykernel_40786/2743543921.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[nan  0.  0. ...  5. nan  6.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, col] = remove_outliers(df[col].fillna(0))
# /var/folders/53/tlvpf6d56dx58q4nxdlvljmh0000gn/T/ipykernel_40786/2743543921.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[nan  2. 20. ...  2.  3.  0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, col] = remove_outliers(df[col].fillna(0))

# %%
plot_boxplots(df, box_cols)

# %%
df_filtered_1['driver_avg_speed'].asfreq
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df_filtered_1['driver_avg_speed'].asfreq
#
# NameError: name 'df_filtered_1' is not defined

# %% [markdown]
# ### 2.3. drivers avg speed plot discretised

# %%
df
# Out:
#        resultId  raceId  driverId  constructorId  grid  race_rank  statusId  \
# 0             1      18         1              1     1          2         1
# 1             2      18         2              2     5          3         1
# 2             3      18         3              3     7          5         1
# 3             4      18         4              4    11          7         1
# 4             5      18         5              1     3          1         1
# ...         ...     ...       ...            ...   ...        ...       ...
# 26075     26081    1110       817            213    19         15         1
# 26076     26082    1110       858              3    18          9         1
# 26077     26083    1110       807            210     0          4         1
# 26078     26084    1110       832              6     4         19       130
# 26079     26085    1110       857              1     5          0       130
#
#        year  round  circuitId  ...  race_end_in_2019  race_end_in_2020  \
# 0      2008      1          1  ...               NaN               NaN
# 1      2008      1          1  ...               0.0               0.0
# 2      2008      1          1  ...               0.0               0.0
# 3      2008      1          1  ...               0.0               0.0
# 4      2008      1          1  ...               0.0               0.0
# ...     ...    ...        ...  ...               ...               ...
# 26075  2023     12         13  ...               8.0               NaN
# 26076  2023     12         13  ...               0.0               0.0
# 26077  2023     12         13  ...               7.0               2.0
# 26078  2023     12         13  ...              10.0              10.0
# 26079  2023     12         13  ...               0.0               0.0
#
#        race_end_in_2021  race_end_in_2022  race_end_in_2023  \
# 0                   NaN               NaN               NaN
# 1                   0.0               0.0               0.0
# 2                   0.0               0.0               0.0
# 3                  11.0              12.0               NaN
# 4                   0.0               0.0               0.0
# ...                 ...               ...               ...
# 26075              13.0              14.0               1.0
# 26076               0.0               0.0               4.0
# 26077               0.0               2.0               5.0
# 26078               NaN              16.0               NaN
# 26079               0.0               0.0               6.0
#
#        driver_most_won_circuit_id  driver_nber_of_races_won  \
# 0                              14                       NaN
# 1                               2                       2.0
# 2                               3                      20.0
# 3                               9                      22.0
# 4                               1                       2.0
# ...                           ...                       ...
# 26075                           1                      16.0
# 26076                           0                       0.0
# 26077                          15                       2.0
# 26078                           7                       3.0
# 26079                           0                       0.0
#
#        driver_nber_of_times_in_top_10  age  season_age
# 0                                 292   39          23
# 1                                 131   47          31
# 2                                 158   39          23
# 3                                 285   43          27
# 4                                  37   43          27
# ...                               ...  ...         ...
# 26075                             128   35          34
# 26076                               2   24          23
# 26077                              91   37          36
# 26078                             105   30          29
# 26079                               4   23          22
#
# [26080 rows x 28 columns]

# %%
bins = [df['driver_avg_speed'].min(), 200, 202, 204, 206, df['driver_avg_speed'].max()]
labels = [1, 2, 3, 4, 5]
categories = pd.cut(df['driver_avg_speed'], bins=bins, labels=labels, include_lowest=True)

# %%
df['driver_avg_speed'] = categories

# %%
df['driver_avg_speed'].head()
# Out:
# 0    4
# 1    4
# 2    2
# 3    4
# 4    1
# Name: driver_avg_speed, dtype: category
# Categories (5, int64): [1 < 2 < 3 < 4 < 5]

# %%
df_rank_zero = df[(df['race_rank'] == 0) & (df['year'] > 2010)]
df_rank_zero.shape
df = df[df['race_rank'] != 0]
df = pd.concat([df, df_rank_zero], ignore_index=True)
# Out:
# (216, 28)

# %%
df = df[df['race_rank'] != 0]

# %%
df = pd.concat([df, df_rank_zero], ignore_index=True)

# %%
df['race_rank'].value_counts().sort_values(ascending=True)
# Out:
# race_rank
# 24     28
# 23     43
# 22     91
# 21    122
# 0     216
# 20    269
# 19    322
# 18    358
# 17    367
# 16    373
# 15    374
# 8     375
# 14    375
# 10    376
# 11    376
# 13    376
# 9     376
# 7     376
# 12    376
# 5     377
# 6     377
# 4     377
# 3     377
# 1     377
# 2     377
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (7831, 28)
